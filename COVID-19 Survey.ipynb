# %%
#Covid-19 Survey

#typed introduction 
print("Welcome to the COVID-19 Survey")
print("First we will ask you questions based on your symptoms then provide you with the best course of action")
print("This survey is case sensitive so please answer with either Yes or No in order to recieve the best response")
print("I am also not a docter and am just suggesting action based on doctor recommendations")
#asked if they are expieriecing any symptoms
x = input("Do you have a fever or a runny nose? ").capitalize()
y = input("Are you suffering from fatigue or body aches? ").capitalize()
z = input("Do you have a cough or shortness of breath? ").capitalize()
a = input("Are you experiencing nausea, vomitting, and/or daihrea? ").capitalize()
b = input("Do you have a sore throat or a headache? ").capitalize()
e = input("Have you been experiencing persistnt pain or pressure in your chest? ").capitalize()
m = input("Are you expierencing new confusion? ").capitalize()
t = input("Is it hard for you to get up or to stay awake? ").capitalize()
r = input("Do you have bluish lips or face? ").capitalize()


#typed the possibilities and the recommended action
if x == "Yes":
  print("You might the virus and should see if you continue to exibit symptoms")
  print("If you comtinue to experience these symptoms get tested ")
  print("Make sure to continue to practice social distancing and wearing a mask if you have to go outside so that you don't endanger other lives.")
elif y == "Yes":
  print("You might the virus and should see if you continue to exibit symptoms")
  print("Make sure to continue to practice social distancing and wearing a mask if you have to go outside so that you don't endanger other lives.")
  print("If you comtinue to experience these symptoms get tested ")
  print("Make sure to continue to practice social distancing and wearing a mask if you have to go outside so that you don't endanger other lives.")
elif z  == "Yes":
  print("You might the virus and should see if you continue to exibit symptoms")
  print("If you comtinue to experience these symptoms get tested ")
  print("Make sure to continue to practice social distancing and wearing a mask if you have to go outside so that you don't endanger other lives.")
elif  a == "Yes":
  print("You might the virus and should see if you continue to exibit symptoms")
  print("If you comtinue to experience these symptoms get tested ")
  print("Make sure to continue to practice social distancing and wearing a mask if you have to go outside so that you don't endanger other lives.")
elif  b == "Yes":
  print("You might the virus and should see if you continue to exibit symptoms")
  print("If you comtinue to experience these symptoms get tested ")
  print("Make sure to continue to practice social distancing and wearing a mask if you have to go outside so that you don't endanger other lives.")
  
elif x=="Yes" and y == "Yes":
  print("You probably have the virus and should get tested")
  print("Make sure to continue to practice social distancing and wearing a mask if you have to go outside so that you don't endanger other lives.")
elif x=="Yes" and z == "Yes":
  print("You probably have the virus and should get tested")
  print("Make sure to continue to practice social distancing and wearing a mask if you have to go outside so that you don't endanger other lives.")
elif x=="Yes" and a == "Yes":
  print("You probably have the virus and should get tested")
  print("Make sure to continue to practice social distancing and wearing a mask if you have to go outside so that you don't endanger other lives.")
elif x=="Yes" and b == "Yes":
  print("You probably have the virus and should get tested")
  print("Make sure to continue to practice social distancing and wearing a mask if you have to go outside so that you don't endanger other lives.")
elif y=="Yes" and z == "Yes":
  print("You probably have the virus and should get tested")
  print("Make sure to continue to practice social distancing and wearing a mask if you have to go outside so that you don't endanger other lives.")
elif y=="Yes" and a == "Yes":
  print("You probably have the virus and should get tested")
  print("Make sure to continue to practice social distancing and wearing a mask if you have to go outside so that you don't endanger other lives.")
elif y=="Yes" and b == "Yes":
  print("You probably have the virus and should get tested")
  print("Make sure to continue to practice social distancing and wearing a mask if you have to go outside so that you don't endanger other lives.")
elif z=="Yes" and a == "Yes":
  print("You probably have the virus and should get tested")
  print("Make sure to continue to practice social distancing and wearing a mask if you have to go outside so that you don't endanger other lives.")
elif z=="Yes" and b == "Yes":
  print("You probably have the virus and should get tested")
  print("Make sure to continue to practice social distancing and wearing a mask if you have to go outside so that you don't endanger other lives.")
elif a=="Yes" and b == "Yes":
  print("You probably have the virus and should get tested")
  print("Make sure to continue to practice social distancing and wearing a mask if you have to go outside so that you don't endanger other lives.")

elif e == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif m == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif t == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif r == "Yes":
  print("Go to the nearest hospital to recive urgent care")

elif e=="Yes" and m == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif e=="Yes" and t == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif e=="Yes" and r  == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif m=="Yes" and t == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif m=="Yes" and r  == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif t=="Yes" and r  == "Yes":
  print("Go to the nearest hospital to recive urgent care")

elif x=="Yes" and y=="Yes" and e == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif x=="Yes" and z=="Yes" and e == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif x=="Yes" and a=="Yes" and e == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif x=="Yes" and b=="Yes" and e == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif y=="Yes" and z=="Yes" and e == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif y=="Yes" and a=="Yes" and e == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif y=="Yes" and b=="Yes" and e == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif z=="Yes" and a=="Yes" and e == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif z=="Yes" and b=="Yes" and e == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif a=="Yes" and b=="Yes" and e == "Yes":
  print("Go to the nearest hospital to recive urgent care")

elif x=="Yes" and y=="Yes" and m == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif x=="Yes" and z=="Yes" and m == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif x=="Yes" and a=="Yes" and m == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif x=="Yes" and b=="Yes" and m == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif y=="Yes" and z=="Yes" and m == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif y=="Yes" and a=="Yes" and m == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif y=="Yes" and b=="Yes" and m == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif z=="Yes" and a=="Yes" and m == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif z=="Yes" and b=="Yes" and m == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif a=="Yes" and b=="Yes" and m == "Yes":
  print("Go to the nearest hospital to recive urgent care")

elif x=="Yes" and y=="Yes" and r == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif x=="Yes" and z=="Yes" and r == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif x=="Yes" and a=="Yes" and r == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif x=="Yes" and b=="Yes" and r == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif y=="Yes" and z=="Yes" and r == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif y=="Yes" and a=="Yes" and r == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif y=="Yes" and b=="Yes" and r == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif z=="Yes" and a=="Yes" and r == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif z=="Yes" and b=="Yes" and r == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif a=="Yes" and b=="Yes" and r == "Yes":
  print("Go to the nearest hospital to recive urgent care")

elif x=="Yes" and y=="Yes" and t == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif x=="Yes" and z=="Yes" and t == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif x=="Yes" and a=="Yes" and t == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif x=="Yes" and b=="Yes" and t == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif y=="Yes" and z=="Yes" and t == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif y=="Yes" and a=="Yes" and t == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif y=="Yes" and b=="Yes" and t == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif z=="Yes" and a=="Yes" and t == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif z=="Yes" and b=="Yes" and t == "Yes":
  print("Go to the nearest hospital to recive urgent care")
elif a=="Yes" and b=="Yes" and t == "Yes":
  print("Go to the nearest hospital to recive urgent care")

else:
  print("You probably dont have the virus!")
# Out:
#   File "<ipython-input-2-c554b58d4639>", line 177
#     elif a== and b and t == "Yes":
#                ^
# SyntaxError: invalid syntax

# %%
# Out:
# LLALA:: asdffwa

# %%
# Out:
# Asdffwa
