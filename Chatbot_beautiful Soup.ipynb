# %%
pip install google
# Out:
# Requirement already satisfied: google in c:\users\dell\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\dell\anaconda3\lib\site-packages (from google) (4.8.0)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\dell\anaconda3\lib\site-packages (from beautifulsoup4->google) (1.9.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
try:
    from googlesearch import search
except ImportError:
    print("No module named 'google' found")

# %%
query="kakashi"

# %%
for j in search(query,tld="co.in",num=10,stop=10,pause=2):
    print(j)
# Out:
# https://www.pinterest.com/pin/600878775268077126/
# https://en.wikipedia.org/wiki/Kakashi_Hatake
# https://naruto.fandom.com/wiki/Kakashi_Hatake
# https://naruto.fandom.com/wiki/Sakumo_Hatake
# https://naruto.fandom.com/wiki/Hatake_Clan
# https://naruto.fandom.com/wiki/Lightning_Release:_Purple_Electricity
# https://naruto.fandom.com/wiki/Team_Ro
# https://narutoshippuuden.fandom.com/wiki/Hatake_Kakashi
# https://www.youtube.com/watch?v=GibOH_OqNT4
# https://screenrant.com/naruto-kakashi-question-mystery-answered/

# %%
pip install request
# Out:
# Requirement already satisfied: request in c:\users\dell\anaconda3\lib\site-packages (0.0.0)
# Requirement already satisfied: get in c:\users\dell\anaconda3\lib\site-packages (from request) (0.0.0)
# Requirement already satisfied: post in c:\users\dell\anaconda3\lib\site-packages (from request) (0.0.0)
# Requirement already satisfied: query-string in c:\users\dell\anaconda3\lib\site-packages (from get->request) (0.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/List_of_Indian_film_actors"

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

for a in soup.find_all('a', href=True):
    print ("Found the URL:", a['href'])
# Out:
# Found the URL: /wiki/Wikipedia:Protection_policy#semi
# Found the URL: #mw-head
# Found the URL: #searchInput
# Found the URL: /wiki/Wikipedia:WikiProject_Lists#Incomplete_lists
# Found the URL: https://en.wikipedia.org/w/index.php?title=List_of_Indian_film_actors&action=edit
# Found the URL: /wiki/Cinema_of_India
# Found the URL: #A
# Found the URL: #B
# Found the URL: #C
# Found the URL: #D
# Found the URL: #E
# Found the URL: #F
# Found the URL: #G
# Found the URL: #H
# Found the URL: #I
# Found the URL: #J
# Found the URL: #K
# Found the URL: #L
# Found the URL: #M
# Found the URL: #N
# Found the URL: #O
# Found the URL: #P
# Found the URL: #Q
# Found the URL: #R
# Found the URL: #S
# Found the URL: #T
# Found the URL: #U
# Found the URL: #V
# Found the URL: #W
# Found the URL: #X
# Found the URL: #Y
# Found the URL: #Z
# Found the URL: /wiki/Amitabh_Bachchan
# Found the URL: /wiki/Bollywood
# Found the URL: /wiki/File:Actor_Kamal_Hassan_addressing_at_the_inaugural_ceremony_of_the_44th_International_Film_Festival_of_India_(IFFI-2013),_in_Panaji,_Goa_on_November_20,_2013.jpg
# Found the URL: /wiki/Kamal_Haasan
# Found the URL: /wiki/Kollywood
# Found the URL: /wiki/File:Mohanlal_1.jpg
# Found the URL: /wiki/Mohanlal
# Found the URL: /wiki/Malayalam_Cinema
# Found the URL: /wiki/File:K._Chiranjeevi_addressing_at_the_Plenary_Session_%E2%80%93_India%E2%80%99s_Soft_Power,_at_the_12th_Pravasi_Bharatiya_Divas_%E2%80%98Engaging_Diaspora_Connecting_Across_Generation%E2%80%99,_in_New_Delhi_on_January_08,_2014.jpg
# Found the URL: /wiki/Chiranjeevi
# Found the URL: /wiki/Tollywood_(Telugu)
# Found the URL: /wiki/A._K._Hangal
# Found the URL: /wiki/Aadhi_(actor)
# Found the URL: /wiki/Aadi_(Telugu_actor)
# Found the URL: /wiki/Aamir_Khan
# Found the URL: /wiki/Aashish_Chaudhary
# Found the URL: /wiki/Abbas_(actor)
# Found the URL: /wiki/Abhay_Deol
# Found the URL: /wiki/Abhijeeth
# Found the URL: /wiki/Abhishek_Bachchan
# Found the URL: /wiki/Abhishek_Banerjee
# Found the URL: /wiki/Abhishek_Chatterjee
# Found the URL: /wiki/Abhishek_Gowda
# Found the URL: /wiki/Abhimanyu_Singh
# Found the URL: /wiki/Abijeet_Duddala
# Found the URL: /wiki/Abir_Chatterjee
# Found the URL: /wiki/Achyuth_Kumar
# Found the URL: /wiki/Adharvaa
# Found the URL: /wiki/Adhyayan_Suman
# Found the URL: /wiki/Adil_Hussain
# Found the URL: /wiki/Aditya_Babu
# Found the URL: /wiki/Aditya_Pancholi
# Found the URL: /wiki/Aditya_Kumar
# Found the URL: /wiki/Aditya_Roy_Kapur
# Found the URL: /wiki/Aditya_Seal
# Found the URL: /wiki/Adoor_Bhasi
# Found the URL: /wiki/Aftab_Shivdasani
# Found the URL: /wiki/Ahuti_Prasad
# Found the URL: /wiki/Ajay_Devgan
# Found the URL: /wiki/Ajay_Rao
# Found the URL: /wiki/Ajaz_Khan
# Found the URL: /wiki/Ajinkya_Dev
# Found the URL: /wiki/Ajit_Khan
# Found the URL: /wiki/Ajith_Kumar
# Found the URL: /wiki/Ajmal_Ameer
# Found the URL: /wiki/Aju_Varghese
# Found the URL: /wiki/Akhil_(Telugu_actor)
# Found the URL: /wiki/Akhilendra_Mishra
# Found the URL: /wiki/Akshay_Anand
# Found the URL: /wiki/Akshay_Kumar
# Found the URL: /wiki/Akshaye_Khanna
# Found the URL: /wiki/Akshay_Oberoi
# Found the URL: /wiki/Akul_Balaji
# Found the URL: /wiki/Ali_(actor)
# Found the URL: /wiki/Ali_Fazal
# Found the URL: /wiki/Ali_Zafar
# Found the URL: /wiki/Allari_Naresh
# Found the URL: /wiki/Allu_Arjun
# Found the URL: /wiki/Allu_Sirish
# Found the URL: /wiki/Alok_Nath
# Found the URL: /wiki/Amar_Talwar
# Found the URL: /wiki/Ambareesh
# Found the URL: /wiki/Amitabh_Bachchan
# Found the URL: /wiki/Amit_Sadh
# Found the URL: /wiki/Amit_Sial
# Found the URL: /wiki/Amjad_Khan_(actor)
# Found the URL: /wiki/Ammy_Virk
# Found the URL: /wiki/Amol_Palekar
# Found the URL: /wiki/Amrish_Puri
# Found the URL: /wiki/Anand_Tiwari
# Found the URL: /wiki/Ananth_Nag
# Found the URL: /wiki/Angad_Bedi
# Found the URL: /wiki/Anil_Kapoor
# Found the URL: /wiki/Aniruddha_Jatkar
# Found the URL: /wiki/Anjan_Srivastav
# Found the URL: /wiki/Ankush_Chaudhari
# Found the URL: /wiki/Ankush_Hazra
# Found the URL: /wiki/Annu_Kapoor
# Found the URL: /wiki/Anoop_Kumar
# Found the URL: /wiki/Anoop_Menon
# Found the URL: /wiki/Anshuman_Jha
# Found the URL: /wiki/Anubhav_Mohanty
# Found the URL: /wiki/Anuj_Gurwara
# Found the URL: /wiki/Anupam_Kher
# Found the URL: /wiki/Anup_Soni
# Found the URL: /wiki/Anurag_Kashyap
# Found the URL: /wiki/Aparshakti_Khurana
# Found the URL: /wiki/Apurva_Agnihotri
# Found the URL: /wiki/Aravind_Akash
# Found the URL: /wiki/Arbaaz_Khan
# Found the URL: /wiki/Arif_Zakaria
# Found the URL: /wiki/Arjan_Bajwa
# Found the URL: /wiki/Arjun_Kapoor
# Found the URL: /wiki/Arjun_Mathur
# Found the URL: /wiki/Arjun_Rampal
# Found the URL: /wiki/Arjun_Sarja
# Found the URL: /wiki/Arshad_Warsi
# Found the URL: /wiki/Arun_Sarnaik
# Found the URL: /wiki/Arunoday_Singh
# Found the URL: /wiki/Arvind_Krishna
# Found the URL: /wiki/Arvind_Swamy
# Found the URL: /wiki/Arya_Babbar
# Found the URL: /wiki/Arya_(actor)
# Found the URL: /wiki/Asif_Ali_(actor)
# Found the URL: /wiki/Asif_Basra
# Found the URL: /wiki/Ashish_Vidyarthi
# Found the URL: /wiki/Ashok_(Kannada_actor)
# Found the URL: /wiki/Ashok_Kumar
# Found the URL: /wiki/Asrani
# Found the URL: /wiki/Ashok_Saraf
# Found the URL: /wiki/Ashok_Selvan
# Found the URL: /wiki/Ashutosh_Rana
# Found the URL: /wiki/Attakathi_Dinesh
# Found the URL: /wiki/Atul_Agnihotri
# Found the URL: /wiki/Atul_Kulkarni_(actor_born_1965)
# Found the URL: /wiki/Atul_Parchure
# Found the URL: /wiki/Auditya
# Found the URL: /wiki/Avinash_Tiwary
# Found the URL: /wiki/Avinash
# Found the URL: /wiki/Ayushmann_Khurrana
# Found the URL: /wiki/Anupam_Sharma
# Found the URL: /wiki/B._C._Patil
# Found the URL: /wiki/B._R._Panthulu
# Found the URL: /wiki/Baburaj_(actor)
# Found the URL: /wiki/Babu_Antony
# Found the URL: /wiki/Badshah
# Found the URL: /wiki/Wikipedia:WikiProject_Disambiguation/Fixing_links
# Found the URL: /wiki/Balakrishna_(Kannada_actor)
# Found the URL: /wiki/Balakrishna_Nandamuri
# Found the URL: /wiki/Balan_K._Nair
# Found the URL: /wiki/Balaraj
# Found the URL: /wiki/Balraj_Sahni
# Found the URL: /wiki/Bank_Janardhan
# Found the URL: /wiki/Barun_Sobti
# Found the URL: /wiki/Benjamin_Gilani
# Found the URL: /wiki/Bhagwan_Dada
# Found the URL: /wiki/Bhanu_Chander
# Found the URL: /wiki/Bharat_Bhushan_Bhalla
# Found the URL: /wiki/Bharat_Jadhav
# Found the URL: /wiki/Bharath_Gopi
# Found the URL: /wiki/Bharath_Srinivasan
# Found the URL: /wiki/Bharathiraja
# Found the URL: /wiki/Bank_Janardhan
# Found the URL: /wiki/Bijay_Mohanty
# Found the URL: /wiki/Bijon_Bhattacharya
# Found the URL: /wiki/Biju_Menon
# Found the URL: /wiki/Biswajit_Chatterjee
# Found the URL: /wiki/Bob_Christo
# Found the URL: /wiki/Bobby_Deol
# Found the URL: /wiki/Bobby_Kottarakkara
# Found the URL: /wiki/Bobby_Simha
# Found the URL: /wiki/Boman_Irani
# Found the URL: /wiki/Brahmanandam
# Found the URL: /wiki/Brijendra_Kala
# Found the URL: /wiki/Bullet_Prakash
# Found the URL: /wiki/C._R._Simha
# Found the URL: /wiki/Chandra_Mohan_(Hindi_actor)
# Found the URL: /wiki/Chandra_Mohan_(Telugu_actor)
# Found the URL: /wiki/Chandrachur_Singh
# Found the URL: /wiki/Chandrashekhar
# Found the URL: /wiki/Charan_Raj
# Found the URL: /wiki/Charlie_(actor)
# Found the URL: /wiki/Charu_Hassan
# Found the URL: /wiki/Chetan_Chandra
# Found the URL: /wiki/Chetan_Kumar
# Found the URL: /wiki/Chhabi_Biswas
# Found the URL: /wiki/Chi._Guru_Dutt
# Found the URL: /wiki/Chinni_Jayanth
# Found the URL: /wiki/Chikkanna
# Found the URL: /wiki/Chiranjeevi
# Found the URL: /wiki/Chiranjeevi_Sarja
# Found the URL: /wiki/Chittor_V._Nagaiah
# Found the URL: /wiki/Chunky_Pandey
# Found the URL: /wiki/Crazy_Mohan
# Found the URL: /wiki/Cyrus_Broacha
# Found the URL: /wiki/Cyrus_Sahukar
# Found the URL: /wiki/Dada_Kondke
# Found the URL: /wiki/Dalip_Tahil
# Found the URL: /wiki/Danny_Denzongpa
# Found the URL: /wiki/Dara_Singh
# Found the URL: /wiki/Darshan_(actor)
# Found the URL: /wiki/Darsheel_Safary
# Found the URL: /wiki/H._G._Dattatreya
# Found the URL: /wiki/David_Abraham_Cheulkar
# Found the URL: /wiki/Deepak_Dobriyal
# Found the URL: /wiki/Deepak_Tijori
# Found the URL: /wiki/Dev_(Bengali_actor)
# Found the URL: /wiki/Dev_(Tamil_actor)
# Found the URL: /wiki/Dev_Anand
# Found the URL: /wiki/Dev_Gill
# Found the URL: /wiki/Dev_Mohan
# Found the URL: /wiki/Devan_(actor)
# Found the URL: /wiki/Devaraj
# Found the URL: /wiki/Deven_Verma
# Found the URL: /wiki/Dharmavarapu_Subramanyam
# Found the URL: /wiki/Dharmendra
# Found the URL: /wiki/Dhanush
# Found the URL: /wiki/Dheerendra_Gopal
# Found the URL: /wiki/Dhruva_Sarja
# Found the URL: /wiki/Diganth
# Found the URL: /wiki/Dinesh_(Kannada_actor)
# Found the URL: /wiki/Dingri_Nagaraj
# Found the URL: /wiki/Dino_Morea
# Found the URL: /wiki/Dileep_(actor)
# Found the URL: /wiki/Diljit_Dosanjh
# Found the URL: /wiki/Dilip_Kumar
# Found the URL: /wiki/Dilip_Prabhavalkar
# Found the URL: /wiki/Dinesh_Lal_Yadav
# Found the URL: /wiki/Divyang_Thakkar
# Found the URL: /wiki/Divyendu_Sharma
# Found the URL: /wiki/Doddanna
# Found the URL: /wiki/Dulquer_Salmaan
# Found the URL: /wiki/Duniya_Vijay
# Found the URL: /wiki/Dwarakish
# Found the URL: /wiki/Emraan_Hashmi
# Found the URL: /wiki/Erick_Avari
# Found the URL: /wiki/Fahadh_Faasil
# Found the URL: /wiki/Faisal_Khan
# Found the URL: /wiki/Fardeen_Khan
# Found the URL: /wiki/Farhan_Akhtar
# Found the URL: /wiki/Farooq_Sheikh
# Found the URL: /wiki/Faruk_Kabir
# Found the URL: /wiki/Fawad_Khan
# Found the URL: /wiki/Feroz_Khan_(actor,_born_1939)
# Found the URL: /wiki/Fish_Venkat
# Found the URL: /wiki/G._K._Govinda_Rao
# Found the URL: /wiki/G._V._Iyer
# Found the URL: /wiki/Gajendra_Chauhan
# Found the URL: /wiki/Ganesh_(actor)
# Found the URL: /wiki/Ganesh_Venkatraman
# Found the URL: /wiki/Gangadhar_(Kannada_actor)
# Found the URL: /wiki/Gaurav_Chanana
# Found the URL: /wiki/Gautham_Karthik
# Found the URL: /wiki/Gautham_Menon
# Found the URL: /wiki/Gavie_Chahal
# Found the URL: /wiki/Gemini_Ganesan
# Found the URL: /wiki/Gippy_Grewal
# Found the URL: /wiki/Gireesh_Sahedev
# Found the URL: /wiki/Giri_Babu
# Found the URL: /wiki/Girish_Karnad
# Found the URL: /wiki/Girish_Kumar_Taurani
# Found the URL: /wiki/Gufi_Paintal
# Found the URL: /wiki/Gurmeet_Choudhary
# Found the URL: /wiki/Gopal_Dutt
# Found the URL: /wiki/Goundamani
# Found the URL: /wiki/Govinda_(actor)
# Found the URL: /wiki/Gubbi_Veeranna
# Found the URL: /wiki/Gulshan_Devaiah
# Found the URL: /wiki/Gulshan_Grover
# Found the URL: /wiki/Gummadi_Venkateswara_Rao
# Found the URL: /wiki/Gurdas_Maan
# Found the URL: /wiki/Guru_Dutt
# Found the URL: /wiki/Gurukiran
# Found the URL: /wiki/Guruprasad
# Found the URL: /wiki/Gopichand_Lagadapati
# Found the URL: /wiki/Hamsavardhan
# Found the URL: /wiki/Harbhajan_Mann
# Found the URL: /wiki/Hardy_Sandhu
# Found the URL: /wiki/Harikrishna_Nandamuri
# Found the URL: /wiki/Harish_Kumar_(actor)
# Found the URL: /wiki/Harish_Raj
# Found the URL: /wiki/Harsh_Mayar
# Found the URL: /wiki/Harshvardhan_Kapoor
# Found the URL: /wiki/Harshvardhan_Rane
# Found the URL: /wiki/Harisree_Ashokan
# Found the URL: /wiki/Harman_Baweja
# Found the URL: /wiki/Himansh_Kohli
# Found the URL: /wiki/Hiran_Chatterjee
# Found the URL: /wiki/Hiten_Paintal
# Found the URL: /wiki/Hiten_Tejwani
# Found the URL: /wiki/Hrithik_Roshan
# Found the URL: /wiki/Himesh_Reshammiya
# Found the URL: /wiki/Honnappa_Bhagavathar
# Found the URL: /wiki/Honnavalli_Krishna
# Found the URL: /wiki/Hunsur_Krishnamurthy
# Found the URL: /wiki/I._S._Johar
# Found the URL: /wiki/Iftekar
# Found the URL: /wiki/Imaad_Shah
# Found the URL: /wiki/Imran_Abbas_Naqvi
# Found the URL: /wiki/Imran_Hasnee
# Found the URL: /wiki/Imran_Khan_(Bollywood_actor)
# Found the URL: /wiki/Inder_Kumar
# Found the URL: /wiki/Indrajith_Sukumaran
# Found the URL: /wiki/Indrans
# Found the URL: /wiki/Inderpal_Singh
# Found the URL: /wiki/Innocent_Vincent
# Found the URL: /wiki/Irrfan_Khan
# Found the URL: /wiki/Inaamulhaq
# Found the URL: /wiki/Ishaan_Khattar
# Found the URL: /wiki/Ivan_Rodriguez
# Found the URL: /wiki/J._P._Chandrababu
# Found the URL: /wiki/J._V._Somayajulu
# Found the URL: /wiki/Jaaved_Jaffrey
# Found the URL: /wiki/Jackie_Shroff
# Found the URL: /wiki/Jackky_Bhagnani
# Found the URL: /wiki/Jagadish
# Found the URL: /wiki/Jagapati_Babu
# Found the URL: /wiki/Jagathy_Sreekumar
# Found the URL: /wiki/Jagdeep
# Found the URL: /wiki/Jagdish_Raj
# Found the URL: /wiki/Jaggesh
# Found the URL: /wiki/Jai_(actor)
# Found the URL: /wiki/Jaideep_Ahlawat
# Found the URL: /wiki/Jaishankar
# Found the URL: /wiki/Jai_Akash
# Found the URL: /wiki/Jai_Jagadish
# Found the URL: /wiki/Jameel_Khan
# Found the URL: /wiki/Jaspal_Bhatti
# Found the URL: /wiki/Jatin_Bora
# Found the URL: /wiki/Javed_Sheikh
# Found the URL: /wiki/Jaya_Prakash_Reddy
# Found the URL: /wiki/Jayadev_Mohan
# Found the URL: /wiki/Jayam_Ravi
# Found the URL: /wiki/Jayan
# Found the URL: /wiki/Jayant_(actor)
# Found the URL: /wiki/Jayaram
# Found the URL: /wiki/Jayram_Karthik
# Found the URL: /wiki/Jayasurya
# Found the URL: /wiki/Jeet_(actor)
# Found the URL: /wiki/Jeetendra
# Found the URL: /wiki/Jeeva_(Telugu_actor)
# Found the URL: /wiki/Jeevan_(actor)
# Found the URL: /wiki/Jhanak_Shukla
# Found the URL: /wiki/Jiiva
# Found the URL: /wiki/Jim_Sarbh
# Found the URL: /wiki/Jimmy_Shergill
# Found the URL: /wiki/Jisshu_Sengupta
# Found the URL: /wiki/Jithan_Ramesh
# Found the URL: /wiki/Joe_Simon_(film_director)
# Found the URL: /wiki/John_Abraham_(actor)
# Found the URL: /wiki/Johnny_Lever
# Found the URL: /wiki/Johnny_Walker_(actor)
# Found the URL: /wiki/Joseph_Vijay
# Found the URL: /wiki/Joy_Mukherjee
# Found the URL: /wiki/Jugal_Hansraj
# Found the URL: /wiki/K.L._Saigal
# Found the URL: /wiki/K.N._Singh
# Found the URL: /wiki/K._S._Ashwath
# Found the URL: /wiki/Kabir_Bedi
# Found the URL: /wiki/Kadar_Khan
# Found the URL: /wiki/Kaikala_Satyanarayana
# Found the URL: /wiki/Kalabhavan_Mani
# Found the URL: /wiki/Kalyan_Kumar
# Found the URL: /wiki/Kalyan_Ram
# Found the URL: /wiki/Kamaal_Rashid_Khan
# Found the URL: /wiki/Kamal_Haasan
# Found the URL: /wiki/Kapil_Bora
# Found the URL: /wiki/Kapil_Sharma_(comedian)
# Found the URL: /wiki/Karan_(actor)
# Found the URL: /wiki/Karthi
# Found the URL: /wiki/Kartik_Aaryan
# Found the URL: /wiki/Karan_Johar
# Found the URL: /wiki/Karan_Nath
# Found the URL: /wiki/Karan_Singh_Grover
# Found the URL: /wiki/Karan_Kapoor
# Found the URL: /wiki/Karan_Kundra
# Found the URL: /wiki/Karan_Wahi
# Found the URL: /wiki/Karibasavaiah
# Found the URL: /wiki/Karthik_Muthuraman
# Found the URL: /wiki/Karthik_Sivakumar
# Found the URL: /wiki/Karunas
# Found the URL: /wiki/Kashinath_Ghanekar
# Found the URL: /wiki/Kashinath_(actor)
# Found the URL: /wiki/Kay_Kay_Menon
# Found the URL: /wiki/Kayoze_Irani
# Found the URL: /wiki/Keerthiraj
# Found the URL: /wiki/Keshto_Mukherjee
# Found the URL: /wiki/Khesari_Lal_Yadav
# Found the URL: /wiki/Khayyum
# Found the URL: /wiki/Kiku_Sharda
# Found the URL: /wiki/Kiran_Kumar
# Found the URL: /wiki/Kishan_Shrikanth
# Found the URL: /wiki/Kishore_(actor)
# Found the URL: /wiki/Kishore_Kumar
# Found the URL: /wiki/Komal_Kumar
# Found the URL: /wiki/Kona_Venkat
# Found the URL: /wiki/Kota_Srinivasa_Rao
# Found the URL: /wiki/Krushna_Abhishek
# Found the URL: /wiki/Krishna_(Telugu_actor)
# Found the URL: /wiki/Krishna_(Kannada_actor)
# Found the URL: /wiki/Krishnam_Raju
# Found the URL: /wiki/Krishnudu
# Found the URL: /wiki/Kulbhushan_Kharbanda
# Found the URL: /wiki/Kumar_Bangarappa
# Found the URL: /wiki/Kumar_Gaurav
# Found the URL: /wiki/Kumar_Govind
# Found the URL: /wiki/Kumud_Mishra
# Found the URL: /wiki/Kunaal_Roy_Kapur
# Found the URL: /wiki/Kunal_Kapoor
# Found the URL: /wiki/Kunal_Kapoor_(actor)
# Found the URL: /wiki/Kunal_Khemu
# Found the URL: /wiki/Kunal_(actor)
# Found the URL: /wiki/Kunchacko_Boban
# Found the URL: /wiki/Kunigal_Nagabhushan
# Found the URL: /wiki/Kuthiravattam_Pappu
# Found the URL: /wiki/Lavrenti_Lopes
# Found the URL: /wiki/Lawrence_Raghavendra
# Found the URL: /wiki/Laxmikant_Berde
# Found the URL: /wiki/Lekh_Tandon
# Found the URL: /wiki/Lohithaswa
# Found the URL: /wiki/Lokesh
# Found the URL: /wiki/Loknath
# Found the URL: /wiki/Lucky_Ali
# Found the URL: /wiki/Luv_Sinha
# Found the URL: /wiki/Manav_Kaul
# Found the URL: /wiki/M._B._Shetty
# Found the URL: /wiki/M._G._Ramachandran
# Found the URL: /wiki/M._G._Soman
# Found the URL: /wiki/M._K._Raina
# Found the URL: /wiki/M._K._Thyagaraja_Bhagavathar
# Found the URL: /wiki/M._N._Nambiar
# Found the URL: /wiki/M._P._Shankar
# Found the URL: /wiki/M._S._Narayana
# Found the URL: /wiki/M._V._Vasudeva_Rao
# Found the URL: /wiki/Mac_Mohan
# Found the URL: /wiki/Madan_Puri
# Found the URL: /wiki/Madhu_(actor)
# Found the URL: /wiki/Mahendra_Sandhu
# Found the URL: /wiki/Mahesh_Babu
# Found the URL: /wiki/Mahesh_Kothare
# Found the URL: /wiki/Makrand_Deshpande
# Found the URL: /wiki/Malaysia_Vasudevan
# Found the URL: /wiki/Mammootty
# Found the URL: /wiki/Mamik_Singh
# Found the URL: /wiki/Mandeep_Roy
# Found the URL: /wiki/Manish_Chaudhary
# Found the URL: /wiki/Mani_Damodara_Chakyar
# Found the URL: /wiki/Mani_Madhava_Chakyar
# Found the URL: /wiki/Manikuttan
# Found the URL: /wiki/Manish_Raisinghani
# Found the URL: /wiki/Manivannan
# Found the URL: /wiki/Manjot_Singh
# Found the URL: /wiki/Manna_Dey
# Found the URL: /wiki/Manish_Paul
# Found the URL: /wiki/Manoj_Bajpai
# Found the URL: /wiki/Manoj_Joshi_(actor)
# Found the URL: /wiki/Manoj_K._Jayan
# Found the URL: /wiki/Manoj_Kumar
# Found the URL: /wiki/Manoj_Manchu
# Found the URL: /wiki/Manoj_Tiwari
# Found the URL: /wiki/Master_Hirannaiah
# Found the URL: /wiki/Master_Manjunath
# Found the URL: /wiki/Master_Vinayak
# Found the URL: /wiki/Mehar_Mittal
# Found the URL: /wiki/Mehmood_Ali
# Found the URL: /wiki/Meiyang_Chang
# Found the URL: /wiki/Michael_Madhu
# Found the URL: /wiki/Milind_Soman
# Found the URL: /wiki/Mimoh_Chakraborty
# Found the URL: /wiki/Mithun_Chakraborty
# Found the URL: /wiki/Mithun_Tejaswi
# Found the URL: /wiki/Mohan_Agashe
# Found the URL: /wiki/Mohan_Babu
# Found the URL: /wiki/Mohanlal
# Found the URL: /wiki/Mohan_Joshi
# Found the URL: /wiki/Mohan_(actor)
# Found the URL: /wiki/Mohan_Shankar
# Found the URL: /wiki/Mohit_Madaan
# Found the URL: /wiki/Mohit_Marwah
# Found the URL: /wiki/Mohit_Raina
# Found the URL: /wiki/Mohnish_Behl
# Found the URL: /wiki/Motilal_Rajvansh
# Found the URL: /wiki/Mukesh_(actor)
# Found the URL: /wiki/Mukesh_Khanna
# Found the URL: /wiki/Mukesh_Tiwari
# Found the URL: /wiki/Mukkamala
# Found the URL: /wiki/Mukri
# Found the URL: /wiki/Mukhyamantri_Chandru
# Found the URL: /wiki/Mukul_Dev
# Found the URL: /wiki/Murali_(Malayalam_actor)
# Found the URL: /wiki/Murali_Mohan
# Found the URL: /wiki/Murali_(Tamil_actor)
# Found the URL: /wiki/Mysore_Lokesh
# Found the URL: /wiki/Navin_Prabhakar
# Found the URL: /wiki/N._S._Krishnan
# Found the URL: /wiki/Naga_Chaitanya
# Found the URL: /wiki/Naga_Kiran
# Found the URL: /wiki/Akkineni_Nagarjuna
# Found the URL: /wiki/Nagesh
# Found the URL: /wiki/Nagendra_Babu
# Found the URL: /wiki/Nagendra_Prasad
# Found the URL: /wiki/Akkineni_Nageswara_Rao
# Found the URL: /wiki/Nagineedu
# Found the URL: /wiki/Namit_Das
# Found the URL: /wiki/Namit_Shah_(actor)
# Found the URL: /wiki/Nana_Patekar
# Found the URL: /wiki/Nani_(actor)
# Found the URL: /wiki/Narain_(actor)
# Found the URL: /wiki/Narasimharaju_(Kannada_actor)
# Found the URL: /wiki/Narasimharaju_(Telugu_actor)
# Found the URL: /wiki/Narendra_Prasad
# Found the URL: /wiki/Naresh_(actor)
# Found the URL: /wiki/Naseeruddin_Shah
# Found the URL: /wiki/Nassar_(actor)
# Found the URL: /wiki/Navdeep
# Found the URL: /wiki/Nawazuddin_Siddiqui
# Found the URL: /wiki/Neeraj_Kabi
# Found the URL: /wiki/Nedumudi_Venu
# Found the URL: /wiki/Negro_Johnny
# Found the URL: /wiki/Neil_Nitin_Mukesh
# Found the URL: /wiki/Nikhil_Gowda
# Found the URL: /wiki/Nikhil_Siddharth
# Found the URL: /wiki/Nikitin_Dheer
# Found the URL: /wiki/Nilu_Phule
# Found the URL: /wiki/Ninad_Kamat
# Found the URL: /wiki/Nissar_Khan
# Found the URL: /wiki/Nithin
# Found the URL: /wiki/Nivin_Pauly
# Found the URL: /wiki/N._T._Rama_Rao
# Found the URL: /wiki/N._T._Rama_Rao_Jr.
# Found the URL: /wiki/Nandish_Sandhu
# Found the URL: /wiki/Nazir_Hussain
# Found the URL: /wiki/Naveen_Kasturia
# Found the URL: /wiki/Naveen_Polishetty
# Found the URL: /wiki/Omkar_Kapoor
# Found the URL: /wiki/Oduvil_Unnikrishnan
# Found the URL: /wiki/Om_Prakash
# Found the URL: /wiki/Om_Puri
# Found the URL: /wiki/Om_Shivpuri
# Found the URL: /wiki/Omi_Vaidya
# Found the URL: /wiki/Pankaj_Dheer
# Found the URL: /wiki/Pankaj_Kapoor
# Found the URL: /wiki/Pankaj_Tripathi
# Found the URL: /wiki/Parambrata_Chatterjee
# Found the URL: /wiki/Paresh_Rawal
# Found the URL: /wiki/Parikshit_Sahni
# Found the URL: /wiki/Parmeet_Sethi
# Found the URL: /wiki/Parvin_Dabas
# Found the URL: /wiki/Parzan_Dastur
# Found the URL: /wiki/Pasupathy
# Found the URL: /wiki/Pawan_Kalyan
# Found the URL: /wiki/Pinchoo_Kapoor
# Found the URL: /wiki/Pitobash
# Found the URL: /wiki/Piyush_Mishra
# Found the URL: /wiki/Prabal_Panjabi
# Found the URL: /wiki/Prabhas_Raju_Uppalapati
# Found the URL: /wiki/Prabhu_Deva
# Found the URL: /wiki/Prabhu_Ganesan
# Found the URL: /wiki/Pradeep_Kumar
# Found the URL: /wiki/Pradeep_Pandey
# Found the URL: /wiki/Pradeep_Rawat_(actor)
# Found the URL: /wiki/Prajwal_Devaraj
# Found the URL: /wiki/Prakash_Raj
# Found the URL: /wiki/Pran_(actor)
# Found the URL: /wiki/Pranav_Mohanlal
# Found the URL: /wiki/Prasadbabu
# Found the URL: /wiki/Prasanna_(actor)
# Found the URL: /wiki/Prasenjit_Chatterjee
# Found the URL: /wiki/Prashant_Damle
# Found the URL: /wiki/Prashanta_Nanda
# Found the URL: /wiki/Prashanth_Thyagarajan
# Found the URL: /wiki/Prateik_Babbar
# Found the URL: /wiki/Kuri_Prathap
# Found the URL: /wiki/Prem_(director)
# Found the URL: /wiki/Prem_Chopra
# Found the URL: /wiki/Prem_Kumar_(Kannada_actor)
# Found the URL: /wiki/Prem_Nath
# Found the URL: /wiki/Prem_Nazir
# Found the URL: /wiki/Prithviraj_(Telugu_actor)
# Found the URL: /wiki/Prithviraj_Kapoor
# Found the URL: /wiki/Prithviraj_Sukumaran
# Found the URL: /wiki/Purushottam_Laxman_Deshpande
# Found the URL: /wiki/Pulkit_Samrat
# Found the URL: /wiki/Puneet_Issar
# Found the URL: /wiki/Puneet_Rajkumar
# Found the URL: /wiki/Puri_Jagannadh
# Found the URL: /wiki/Pawan_Singh
# Found the URL: /wiki/R._Madhavan
# Found the URL: /wiki/Raaj_Kumar
# Found the URL: /wiki/Raghav_Juyal
# Found the URL: /wiki/Raghavendra_Rajkumar
# Found the URL: /wiki/Raghu_Babu
# Found the URL: /wiki/Raghu_Mukherjee
# Found the URL: /wiki/Raghubir_Yadav
# Found the URL: /wiki/Raghuvaran
# Found the URL: /wiki/Rahman_(actor)
# Found the URL: /wiki/Rahul_Roy
# Found the URL: /wiki/Rahul_Bose
# Found the URL: /wiki/Rahul_Dev
# Found the URL: /wiki/Raja_Shankar
# Found the URL: /wiki/Raj_Babbar
# Found the URL: /wiki/Raj_Kapoor
# Found the URL: /wiki/Rajanand
# Found the URL: /wiki/Rajesh_Sharma_(actor)
# Found the URL: /wiki/Rajesh_Sharma_(Malayalam_actor)
# Found the URL: /wiki/Rajkummar_Rao
# Found the URL: /wiki/Rajat_Barmecha
# Found the URL: /wiki/Rajendra_Gupta
# Found the URL: /wiki/Rajendra_Kumar
# Found the URL: /wiki/Rajendra_Nath
# Found the URL: /wiki/Rajesh_(Kannada_actor)
# Found the URL: /wiki/Rajesh_Khanna
# Found the URL: /wiki/Rajesh_Khattar
# Found the URL: /wiki/Rajesh_Krishnan
# Found the URL: /wiki/Rajit_Kapoor
# Found the URL: /wiki/Rajinikanth
# Found the URL: /wiki/Ram_Kapoor
# Found the URL: /wiki/Rajeev_Verma
# Found the URL: /wiki/Rajiv_Kanakala
# Found the URL: /wiki/Rajiv_Kapoor
# Found the URL: /wiki/Rajkumar_(actor)
# Found the URL: /wiki/Rajneesh_Duggal
# Found the URL: /wiki/Rajpal_Yadav
# Found the URL: /wiki/Raju_Srivastav
# Found the URL: /wiki/Rakesh_Bedi
# Found the URL: /wiki/Rakesh_Roshan
# Found the URL: /wiki/Ramakrishna_(Kannada_actor)
# Found the URL: /wiki/Ramki_(actor)
# Found the URL: /wiki/Ram_Charan_Teja
# Found the URL: /wiki/Ramesh_Aravind
# Found the URL: /wiki/Ramesh_Babu
# Found the URL: /wiki/Ramesh_Bhat
# Found the URL: /wiki/Ramesh_Deo
# Found the URL: /wiki/Ramesh_Khanna
# Found the URL: /wiki/Ramkumar
# Found the URL: /wiki/Ram_Pothineni
# Found the URL: /wiki/Ranbir_Kapoor
# Found the URL: /wiki/Randeep_Hooda
# Found the URL: /wiki/Randhir_Kapoor
# Found the URL: /wiki/Ranjeet
# Found the URL: /wiki/Ranveer_Singh
# Found the URL: /wiki/Ranvir_Shorey
# Found the URL: /wiki/Ravi_Babu
# Found the URL: /wiki/Ravi_Kishan
# Found the URL: /wiki/Ravi_Prakash_(Telugu_actor)
# Found the URL: /wiki/P._Ravi_Shankar
# Found the URL: /wiki/Ravi_Teja
# Found the URL: /wiki/Ravichandran_(Tamil_actor)
# Found the URL: /wiki/V._Ravichandran
# Found the URL: /wiki/Raza_Murad
# Found the URL: /wiki/Richard_Rishi
# Found the URL: /wiki/Rishi_Kapoor
# Found the URL: /wiki/Riteish_Deshmukh
# Found the URL: /wiki/Riyaz_Khan
# Found the URL: /wiki/Rockline_Venkatesh
# Found the URL: /wiki/Rohit_Roy
# Found the URL: /wiki/Ronit_Roy
# Found the URL: /wiki/Roshan_Seth
# Found the URL: /wiki/S._Narayan
# Found the URL: /wiki/S_Sathyendra
# Found the URL: /wiki/S._J._Suryaah
# Found the URL: /wiki/S._P._Balasubrahmanyam
# Found the URL: /wiki/S._P._B._Charan
# Found the URL: /wiki/S._Shankar
# Found the URL: /wiki/S._V._Ranga_Rao
# Found the URL: /wiki/Saandip
# Found the URL: /wiki/Sachet_Engineer
# Found the URL: /wiki/Sachin_Pilgaonkar
# Found the URL: /wiki/Sachin_Khedekar
# Found the URL: /wiki/Sadhu_Kokila
# Found the URL: /wiki/Saeed_Jaffrey
# Found the URL: /wiki/Sahil_Khan
# Found the URL: /wiki/Sahil_Shroff
# Found the URL: /wiki/Sahil_Vaid
# Found the URL: /wiki/Sai_Kumar_(Kannada_actor)
# Found the URL: /wiki/Saikumar_(Malayalam_actor)
# Found the URL: /wiki/Saif_Ali_Khan
# Found the URL: /wiki/Sai_Dharam_Tej
# Found the URL: /wiki/Sajid_Khan
# Found the URL: /wiki/Sajjad_Delafrooz
# Found the URL: /wiki/Saleem_Kumar
# Found the URL: /wiki/Salim_Khan
# Found the URL: /wiki/Salman_Khan
# Found the URL: /wiki/Sameer_Dattani
# Found the URL: /wiki/Samir_Kochhar
# Found the URL: /wiki/Samir_Soni
# Found the URL: /wiki/Sampath_(Kannada_actor)
# Found the URL: /wiki/Sampath_Raj
# Found the URL: /wiki/Sandeep_Kulkarni
# Found the URL: /wiki/Sanjay_Dutt
# Found the URL: /wiki/Sanjay_Kapoor
# Found the URL: /wiki/Sanjay_Khan
# Found the URL: /wiki/Sanjay_Mishra_(actor)
# Found the URL: /wiki/Sanjay_Suri
# Found the URL: /wiki/Sanjeev_Bhaskar
# Found the URL: /wiki/Sanjeev_Kumar
# Found the URL: /wiki/Sankaradi
# Found the URL: /wiki/Sanketh_Kashi
# Found the URL: /wiki/Santhanam_(actor)
# Found the URL: /wiki/Sapru_(actor)
# Found the URL: /wiki/Saqib_Saleem
# Found the URL: /wiki/Sarath_Babu
# Found the URL: /wiki/Sarath_Kumar
# Found the URL: /wiki/Sarfaraz_Khan_(actor)
# Found the URL: /wiki/Sathyaraj
# Found the URL: /wiki/Sathyan_(actor)
# Found the URL: /wiki/Sathyan_(Tamil_actor)
# Found the URL: /wiki/Satish_Shah
# Found the URL: /wiki/Sathish_Ninasam
# Found the URL: /wiki/Satyajeet_Puri
# Found the URL: /wiki/Sathyajith_(Kannada_actor)
# Found the URL: /wiki/Saurabh_Shukla
# Found the URL: /wiki/Sayaji_Shinde
# Found the URL: /wiki/Senthil
# Found the URL: /wiki/Shaad_Randhawa
# Found the URL: /wiki/Shaam_(actor)
# Found the URL: /wiki/Shahid_Kapoor
# Found the URL: /wiki/Shah_Rukh_Khan
# Found the URL: /wiki/Shammi_Kapoor
# Found the URL: /wiki/Shani_Mahadevappa
# Found the URL: /wiki/Shankar_(actor)
# Found the URL: /wiki/Shankar_Nag
# Found the URL: /wiki/Sharad_Kelkar
# Found the URL: /wiki/Sharad_Talwalkar
# Found the URL: /wiki/Sharman_Joshi
# Found the URL: /wiki/Sharat_Saxena
# Found the URL: /wiki/Sharath_Babu
# Found the URL: /wiki/Sharath_Kumar
# Found the URL: /wiki/Sharath_Lohitashwa
# Found the URL: /wiki/Sharman_Joshi
# Found the URL: /wiki/Shashank_shende
# Found the URL: /wiki/Shashi_Kapoor
# Found the URL: /wiki/Shashikumar
# Found the URL: /wiki/Shatrughan_Sinha
# Found the URL: /wiki/Shehzad_Khan
# Found the URL: /wiki/Shekhar_Suman
# Found the URL: /wiki/Shiny_Ahuja
# Found the URL: /wiki/Shirish_Kunder
# Found the URL: /wiki/Shivkumar_Subramaniam
# Found the URL: /wiki/Shivam_Patil
# Found the URL: /wiki/Shivarajkumar
# Found the URL: /wiki/Shobaraj_(actor)
# Found the URL: /wiki/Shreela_Ghosh
# Found the URL: /wiki/Shreyas_Talpade
# Found the URL: /wiki/Shriram_Lagoo
# Found the URL: /wiki/Sibiraj
# Found the URL: /wiki/Siddhant_Chaturvedi
# Found the URL: /wiki/Sidhant_Gupta
# Found the URL: /wiki/Sidharth_Malhotra
# Found the URL: #cite_note-TOI2015SM-1
# Found the URL: #cite_note-IE2015SM-2
# Found the URL: /wiki/Sidharth_Shukla
# Found the URL: /wiki/Siddhanta_Mahapatra
# Found the URL: /wiki/Siddharth_Koirala
# Found the URL: /wiki/Siddharth_Narayan
# Found the URL: /wiki/Sikandar_Kher
# Found the URL: /wiki/Silambarasan_Rajendar
# Found the URL: /wiki/Sihi_Kahi_Chandru
# Found the URL: /wiki/Sikandar_Kher
# Found the URL: /wiki/Siva_Reddy
# Found the URL: /wiki/Sivaji_Ganesan
# Found the URL: /wiki/Sivakarthikeyan
# Found the URL: /wiki/Sivakumar
# Found the URL: /wiki/Sobhan_Babu
# Found the URL: /wiki/Sohail_Khan
# Found the URL: /wiki/Soham_Chakraborty
# Found the URL: /wiki/Sohrab_Modi
# Found the URL: /wiki/Sonu_Nigam
# Found the URL: /wiki/Sonu_Sood
# Found the URL: /wiki/Sooraj_Pancholi_(actor)
# Found the URL: /wiki/Sreenivasan_(actor)
# Found the URL: /wiki/Sri_Murali
# Found the URL: /wiki/Sridhar_(Kannada_actor)
# Found the URL: /wiki/Raghumudri_Srihari
# Found the URL: /wiki/Srikanth_(Tamil_actor,_born_1979)
# Found the URL: /wiki/Meka_Srikanth
# Found the URL: /wiki/Srinagar_Kitty
# Found the URL: /wiki/Srinath
# Found the URL: /wiki/Sundeep_Kishan
# Found the URL: /wiki/Srinivasa_Murthy
# Found the URL: /wiki/Srinivasa_Reddy
# Found the URL: /wiki/Srujan_Lokesh
# Found the URL: /wiki/Subbaraju
# Found the URL: /wiki/Subbaraya_Sharma
# Found the URL: /wiki/Subrat_Dutta
# Found the URL: /wiki/Suchindra_Bali
# Found the URL: /wiki/Sudeep
# Found the URL: /wiki/Sudheer_(Kannada_actor)
# Found the URL: /wiki/Subodh_Bhave
# Found the URL: /wiki/Sudheer_Babu
# Found the URL: /wiki/Sudhir_Dalvi
# Found the URL: /wiki/Sujan_Mukhopadhyay
# Found the URL: #cite_note-Gomolo2012NM-3
# Found the URL: #cite_note-WashingtonBanglaRoad2012NM-4
# Found the URL: /wiki/Sukumaran
# Found the URL: /wiki/Suman_Setty
# Found the URL: /wiki/Suman_(actor)
# Found the URL: /wiki/Sumanth
# Found the URL: /wiki/Sumeet_Raghavan
# Found the URL: /wiki/Sundar_Krishna_Urs
# Found the URL: /wiki/Sundar_Raj
# Found the URL: /wiki/Suneil_Anand
# Found the URL: /wiki/Sunil_(Kannada_actor)
# Found the URL: /wiki/Sunil_Dutt
# Found the URL: /wiki/Sunil_Grover
# Found the URL: /wiki/Sunil_Raoh
# Found the URL: /wiki/Sunil_Shetty
# Found the URL: /wiki/Sunil_(actor)
# Found the URL: /wiki/Sunny_Deol
# Found the URL: /wiki/Sunny_Gill
# Found the URL: /wiki/Sunny_Nijar
# Found the URL: /wiki/Suresh_(actor)
# Found the URL: /wiki/Suresh_Gopi
# Found the URL: /wiki/Suresh_Heblikar
# Found the URL: /wiki/Suresh_Joachim
# Found the URL: /wiki/Suresh_Menon
# Found the URL: /wiki/Suresh_Oberoi
# Found the URL: /wiki/Surya
# Found the URL: /wiki/Surya_Sivakumar
# Found the URL: /wiki/Suryakant_Mandhare
# Found the URL: /wiki/Sushant_Singh_Rajput
# Found the URL: /wiki/Sushanth
# Found the URL: /wiki/Suthivelu
# Found the URL: /wiki/Sutti_Veerabhadra_Rao
# Found the URL: /wiki/Swwapnil_Joshi
# Found the URL: /wiki/Tabla_Nani
# Found the URL: /wiki/Taher_Shabbir
# Found the URL: /wiki/Tahir_Raj_Bhasin
# Found the URL: /wiki/Tanay_Chheda
# Found the URL: /wiki/Tanikella_Bharani
# Found the URL: /wiki/Tapas_Paul
# Found the URL: /wiki/Taraka_Ratna
# Found the URL: /wiki/Tarun_Arora
# Found the URL: /wiki/Tarun_Chandra
# Found the URL: /wiki/Tarun_Kumar
# Found the URL: /wiki/Tathagata_Mukherjee
# Found the URL: /wiki/Thagubothu_Ramesh
# Found the URL: /wiki/Thikkurissy_Sukumaran_Nair
# Found the URL: /wiki/Thilakan
# Found the URL: /wiki/Thotta_Tharani
# Found the URL: /wiki/Thalaivasal_Vijay
# Found the URL: /wiki/Tiger_Shroff
# Found the URL: /wiki/Tinnu_Anand
# Found the URL: /wiki/Tiku_Talsania
# Found the URL: /wiki/Tigmanshu_Dhulia
# Found the URL: /wiki/Tom_Alter
# Found the URL: /wiki/Tottempudi_Gopichand
# Found the URL: /wiki/Tusshar_Kapoor
# Found the URL: /wiki/Tushar_Pandey
# Found the URL: /wiki/Uday_Chopra
# Found the URL: /wiki/Uday_Kiran
# Found the URL: /wiki/Udaykumar
# Found the URL: /wiki/Unni_Mukundan
# Found the URL: /wiki/Upen_Patel
# Found the URL: /wiki/Upendra_(actor)
# Found the URL: /wiki/Upendra_Limaye
# Found the URL: /wiki/Utpal_Dutt
# Found the URL: /wiki/Uttam_Kumar
# Found the URL: /wiki/Uttam_Mohanty
# Found the URL: /wiki/Vadivelu
# Found the URL: /wiki/Vajramuni
# Found the URL: /wiki/Varun_Dhawan
# Found the URL: /wiki/Varun_Tej
# Found the URL: /wiki/Varun_Sandesh
# Found the URL: /wiki/Varun_Sharma
# Found the URL: /wiki/Veeru_Devgan
# Found the URL: /wiki/Daggubati_Venkatesh
# Found the URL: /wiki/Vennela_Kishore
# Found the URL: /wiki/Venu_Madhav_(actor)
# Found the URL: /wiki/Vicky_Kaushal
# Found the URL: /wiki/Vidharth
# Found the URL: /wiki/Vidyut_Jammwal
# Found the URL: /wiki/Vijay_Arora
# Found the URL: /wiki/Vijay_(actor)
# Found the URL: /wiki/Vijay_Deverakonda
# Found the URL: /wiki/Duniya_Vijay
# Found the URL: /wiki/Vijay_Raaz
# Found the URL: /wiki/Vijay_Raghavendra
# Found the URL: /wiki/Vijay_Sethupathi
# Found the URL: /wiki/Vijayakanth
# Found the URL: /wiki/Vijayakumar_(actor)
# Found the URL: /wiki/Vijayaraghavan_(actor)
# Found the URL: /wiki/Vijay_Kashi
# Found the URL: /wiki/Vijay_Varma
# Found the URL: /wiki/Vikas_Kalantri
# Found the URL: /wiki/Vikas_Sethi
# Found the URL: /wiki/Vikram_Gokhale
# Found the URL: /wiki/Vikram_(actor)
# Found the URL: /wiki/Vikram_Prabhu
# Found the URL: /wiki/Vikram_Singh_Chauhan
# Found the URL: /wiki/Vikrant_Massey
# Found the URL: /wiki/Vikranth
# Found the URL: /wiki/Vimal_(actor)
# Found the URL: /wiki/Vinay_Apte
# Found the URL: /wiki/Vinay_Pathak
# Found the URL: /wiki/Vinay_Virmani
# Found the URL: /wiki/Vinayak_Joshi
# Found the URL: /wiki/Vindu_Dara_Singh
# Found the URL: /wiki/Vineeth
# Found the URL: /wiki/Vineet_Kumar_Singh
# Found the URL: /wiki/Vineeth_Sreenivasan
# Found the URL: /wiki/Vinod_Khanna
# Found the URL: /wiki/Vinod_Mehra
# Found the URL: /wiki/Vipin_Sharma
# Found the URL: /wiki/Vir_Das
# Found the URL: /wiki/Vishal_Jethwa
# Found the URL: /wiki/Vishal_Krishna
# Found the URL: /wiki/Vishal_Karwal
# Found the URL: /wiki/Vishnu_Manchu
# Found the URL: /wiki/Vishnu_(actor)
# Found the URL: /wiki/Vishnuvardhan_(actor)
# Found the URL: /wiki/Vivaan_Shah
# Found the URL: /wiki/Vivek_(actor)
# Found the URL: /wiki/Vivek_Oberoi
# Found the URL: /wiki/Vivek_Mushran
# Found the URL: /wiki/Vrajesh_Hirjee
# Found the URL: /wiki/VTV_Ganesh
# Found the URL: /wiki/Yash_(Kannada_actor)
# Found the URL: /wiki/Yash_Pandit
# Found the URL: /wiki/Yashmith
# Found the URL: /wiki/Yashpal_Sharma_(actor)
# Found the URL: /wiki/Yash_Tandon
# Found the URL: /wiki/Yash_Tonk
# Found the URL: /wiki/Yatin_Karyekar
# Found the URL: /wiki/Yogesh_(actor)
# Found the URL: /wiki/Yugendran
# Found the URL: /wiki/Yuhi_Sethu
# Found the URL: /wiki/Zayed_Khan
# Found the URL: /wiki/Mohammed_Zeeshan_Ayyub
# Found the URL: /wiki/Zeishan_Quadri
# Found the URL: /wiki/Zubeen_Garg
# Found the URL: /wiki/Zulfi_Syed
# Found the URL: /wiki/List_of_Bhojpuri_cinema_actors
# Found the URL: /wiki/List_of_Bhojpuri_cinema_actresses
# Found the URL: /wiki/List_of_Bollywood_actors
# Found the URL: /wiki/List_of_Bollywood_actresses
# Found the URL: /wiki/List_of_Indian_film_actresses
# Found the URL: /wiki/List_of_Indian_television_actors
# Found the URL: /wiki/List_of_Tamil_film_actors
# Found the URL: /wiki/Lists_of_actors
# Found the URL: #cite_ref-TOI2015SM_1-0
# Found the URL: http://timesofindia.indiatimes.com/entertainment/hindi/bollywood/news/Sidharth-Malhotra-turns-30-ready-for-action/articleshow/45910369.cms
# Found the URL: #cite_ref-IE2015SM_2-0
# Found the URL: http://indianexpress.com/article/entertainment/bollywood/happy-birthday-sidharth-malhotra-ek-villain-actor-gets-ready-for-action-at-30/
# Found the URL: #cite_ref-Gomolo2012NM_3-0
# Found the URL: http://www.gomolo.com/about-neel-mukherjee/798
# Found the URL: #cite_ref-WashingtonBanglaRoad2012NM_4-0
# Found the URL: http://www.washingtonbanglaradio.com/content/34297112-interview-singer-actor-director-neel-mukherjee-bangla-movie-ghente-ghaw-ektu-onyoro
# Found the URL: /wiki/Template:Asian_actors
# Found the URL: /wiki/Template_talk:Asian_actors
# Found the URL: https://en.wikipedia.org/w/index.php?title=Template:Asian_actors&action=edit
# Found the URL: /wiki/List_of_Afghans#Media_people_(including_actors_and_film_directors)
# Found the URL: /wiki/List_of_Armenian_actors
# Found the URL: /wiki/List_of_Azerbaijani_actors
# Found the URL: /wiki/List_of_Bangladeshi_actors
# Found the URL: /wiki/List_of_Bhutanese_actors
# Found the URL: /wiki/List_of_Burmese_actors
# Found the URL: /wiki/List_of_Khmer_film_actors
# Found the URL: /wiki/List_of_Chinese_actresses
# Found the URL: /wiki/List_of_Chinese_actors
# Found the URL: /wiki/List_of_Egyptians#Actors
# Found the URL: /wiki/Lists_of_Indian_actors
# Found the URL: /wiki/List_of_Indian_film_actresses
# Found the URL: /wiki/List_of_Iranian_actresses
# Found the URL: /wiki/List_of_Iranian_actors
# Found the URL: /wiki/List_of_Israeli_actors
# Found the URL: /wiki/List_of_Japanese_actresses
# Found the URL: /wiki/List_of_Japanese_actors
# Found the URL: /wiki/List_of_Jordanian_actors
# Found the URL: /wiki/List_of_Malaysian_actors
# Found the URL: /wiki/List_of_Nepalese_actors
# Found the URL: /wiki/List_of_North_Korean_actors
# Found the URL: /wiki/List_of_Pakistani_actresses
# Found the URL: /wiki/List_of_Pakistani_actors
# Found the URL: /wiki/Lists_of_Philippine_actors
# Found the URL: /wiki/List_of_Filipino_actresses
# Found the URL: /wiki/List_of_Filipino_actors
# Found the URL: /wiki/List_of_South_Korean_actresses
# Found the URL: /wiki/List_of_South_Korean_male_actors
# Found the URL: /wiki/List_of_Sri_Lankan_actors_and_actresses
# Found the URL: /wiki/List_of_Taiwanese_actresses
# Found the URL: /wiki/List_of_Thai_actresses
# Found the URL: /wiki/List_of_Thai_actors
# Found the URL: /wiki/List_of_Turkish_actors
# Found the URL: /wiki/List_of_Uzbekistani_film_actors_and_actresses
# Found the URL: /wiki/List_of_Vietnamese_actors
# Found the URL: https://en.wikipedia.org/w/index.php?title=List_of_Indian_film_actors&oldid=967231070
# Found the URL: /wiki/Help:Category
# Found the URL: /wiki/Category:Indian_male_film_actors
# Found the URL: /wiki/Category:Lists_of_Indian_actors
# Found the URL: /wiki/Category:Wikipedia_pages_semi-protected_against_vandalism
# Found the URL: /wiki/Category:Articles_with_short_description
# Found the URL: /wiki/Category:Use_dmy_dates_from_February_2016
# Found the URL: /wiki/Category:Use_Indian_English_from_February_2016
# Found the URL: /wiki/Category:All_Wikipedia_articles_written_in_Indian_English
# Found the URL: /wiki/Category:Incomplete_lists_from_October_2018
# Found the URL: /wiki/Category:All_articles_with_links_needing_disambiguation
# Found the URL: /wiki/Category:Articles_with_links_needing_disambiguation_from_June_2020
# Found the URL: /wiki/Special:MyTalk
# Found the URL: /wiki/Special:MyContributions
# Found the URL: /w/index.php?title=Special:CreateAccount&returnto=List+of+Indian+film+actors
# Found the URL: /w/index.php?title=Special:UserLogin&returnto=List+of+Indian+film+actors
# Found the URL: /wiki/List_of_Indian_film_actors
# Found the URL: /wiki/Talk:List_of_Indian_film_actors
# Found the URL: /wiki/List_of_Indian_film_actors
# Found the URL: /w/index.php?title=List_of_Indian_film_actors&action=edit
# Found the URL: /w/index.php?title=List_of_Indian_film_actors&action=history
# Found the URL: /wiki/Main_Page
# Found the URL: /wiki/Main_Page
# Found the URL: /wiki/Wikipedia:Contents
# Found the URL: /wiki/Portal:Current_events
# Found the URL: /wiki/Special:Random
# Found the URL: /wiki/Wikipedia:About
# Found the URL: //en.wikipedia.org/wiki/Wikipedia:Contact_us
# Found the URL: https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# Found the URL: //shop.wikimedia.org
# Found the URL: /wiki/Help:Contents
# Found the URL: /wiki/Wikipedia:Community_portal
# Found the URL: /wiki/Special:RecentChanges
# Found the URL: /wiki/Wikipedia:File_Upload_Wizard
# Found the URL: /wiki/Special:WhatLinksHere/List_of_Indian_film_actors
# Found the URL: /wiki/Special:RecentChangesLinked/List_of_Indian_film_actors
# Found the URL: /wiki/Wikipedia:File_Upload_Wizard
# Found the URL: /wiki/Special:SpecialPages
# Found the URL: /w/index.php?title=List_of_Indian_film_actors&oldid=967231070
# Found the URL: /w/index.php?title=List_of_Indian_film_actors&action=info
# Found the URL: /w/index.php?title=Special:CiteThisPage&page=List_of_Indian_film_actors&id=967231070&wpFormIdentifier=titleform
# Found the URL: https://www.wikidata.org/wiki/Special:EntityPage/Q1291621
# Found the URL: /w/index.php?title=Special:ElectronPdf&page=List+of+Indian+film+actors&action=show-download-screen
# Found the URL: /w/index.php?title=List_of_Indian_film_actors&printable=yes
# Found the URL: https://wuu.wikipedia.org/wiki/%E5%AE%9D%E8%8E%B1%E5%9D%9E%E6%BC%94%E5%91%98%E8%A1%A8
# Found the URL: https://ml.wikipedia.org/wiki/%E0%B4%87%E0%B4%A8%E0%B5%8D%E0%B4%A4%E0%B5%8D%E0%B4%AF%E0%B5%BB_%E0%B4%9A%E0%B4%B2%E0%B4%9A%E0%B5%8D%E0%B4%9A%E0%B4%BF%E0%B4%A4%E0%B5%8D%E0%B4%B0_%E0%B4%85%E0%B4%AD%E0%B4%BF%E0%B4%A8%E0%B5%87%E0%B4%A4%E0%B4%BE%E0%B4%95%E0%B5%8D%E0%B4%95%E0%B4%B3%E0%B5%81%E0%B4%9F%E0%B5%86_%E0%B4%AA%E0%B4%9F%E0%B5%8D%E0%B4%9F%E0%B4%BF%E0%B4%95
# Found the URL: https://fa.wikipedia.org/wiki/%D9%81%D9%87%D8%B1%D8%B3%D8%AA_%D8%A8%D8%A7%D8%B2%DB%8C%DA%AF%D8%B1%D8%A7%D9%86_%D9%87%D9%86%D8%AF%DB%8C
# Found the URL: https://sh.wikipedia.org/wiki/Lista_indijskih_glumaca
# Found the URL: https://ta.wikipedia.org/wiki/%E0%AE%87%E0%AE%A8%E0%AF%8D%E0%AE%A4%E0%AE%BF%E0%AE%AF%E0%AE%A4%E0%AF%8D_%E0%AE%A4%E0%AE%BF%E0%AE%B0%E0%AF%88%E0%AE%AA%E0%AF%8D%E0%AE%AA%E0%AE%9F_%E0%AE%A8%E0%AE%9F%E0%AE%BF%E0%AE%95%E0%AE%B0%E0%AF%8D%E0%AE%95%E0%AE%B3%E0%AF%8D_%E0%AE%AA%E0%AE%9F%E0%AF%8D%E0%AE%9F%E0%AE%BF%E0%AE%AF%E0%AE%B2%E0%AF%8D
# Found the URL: https://ms.wikipedia.org/wiki/Senarai_pelakon_lelaki_filem_India
# Found the URL: https://nl.wikipedia.org/wiki/Lijst_van_Indiase_acteurs
# Found the URL: https://ur.wikipedia.org/wiki/%D9%81%DB%81%D8%B1%D8%B3%D8%AA_%D8%A8%DA%BE%D8%A7%D8%B1%D8%AA%DB%8C_%D9%81%D9%84%D9%85%DB%8C_%D8%A7%D8%AF%D8%A7%DA%A9%D8%A7%D8%B1
# Found the URL: https://bn.wikipedia.org/wiki/%E0%A6%AD%E0%A6%BE%E0%A6%B0%E0%A6%A4%E0%A7%80%E0%A6%AF%E0%A6%BC_%E0%A6%9A%E0%A6%B2%E0%A6%9A%E0%A7%8D%E0%A6%9A%E0%A6%BF%E0%A6%A4%E0%A7%8D%E0%A6%B0_%E0%A6%85%E0%A6%AD%E0%A6%BF%E0%A6%A8%E0%A7%87%E0%A6%A4%E0%A6%BE%E0%A6%A6%E0%A7%87%E0%A6%B0_%E0%A6%A4%E0%A6%BE%E0%A6%B2%E0%A6%BF%E0%A6%95%E0%A6%BE
# Found the URL: https://vi.wikipedia.org/wiki/Danh_s%C3%A1ch_di%E1%BB%85n_vi%C3%AAn_%E1%BA%A4n_%C4%90%E1%BB%99
# Found the URL: https://hi.wikipedia.org/wiki/%E0%A4%AD%E0%A4%BE%E0%A4%B0%E0%A4%A4%E0%A5%80%E0%A4%AF_%E0%A4%AB%E0%A4%BC%E0%A4%BF%E0%A4%B2%E0%A5%8D%E0%A4%AE_%E0%A4%85%E0%A4%AD%E0%A4%BF%E0%A4%A8%E0%A5%87%E0%A4%A4%E0%A4%BE%E0%A4%93%E0%A4%82_%E0%A4%95%E0%A5%80_%E0%A4%B8%E0%A5%82%E0%A4%9A%E0%A5%80
# Found the URL: https://ckb.wikipedia.org/wiki/%D9%BE%DB%8E%DA%95%D8%B3%D8%AA%DB%8C_%D8%A6%DB%95%DA%A9%D8%AA%DB%95%D8%B1%DB%95_%DA%BE%DB%8C%D9%86%D8%AF%DB%8C%DB%8C%DB%95%DA%A9%D8%A7%D9%86
# Found the URL: https://ps.wikipedia.org/wiki/%D8%AF_%D9%87%D9%86%D8%AF%D9%8A_%D9%81%D9%84%D9%85%D9%88%D9%86%D9%88_%D8%AF_%D9%86%D8%A7%D8%B1%DB%8C%D9%86%D9%87_%D9%84%D9%88%D8%A8%D8%BA%D8%A7%DA%93%D9%88_%D9%84%DA%93%D9%84%DB%8C%DA%A9_(%D9%86%D9%88%D9%85%D9%84%DA%93)
# Found the URL: https://tg.wikipedia.org/wiki/%D0%A0%D3%AF%D0%B8%D1%85%D0%B0%D1%82%D0%B8_%D2%B3%D1%83%D0%BD%D0%B0%D1%80%D0%BF%D0%B5%D1%88%D0%B0%D2%B3%D0%BE%D0%B8_(%D0%B0%D0%BA%D1%82%D1%91%D1%80%D2%B3%D0%BE)_%D2%B2%D0%B8%D0%BD%D0%B4%D1%83%D1%81%D1%82%D0%BE%D0%BD
# Found the URL: https://as.wikipedia.org/wiki/%E0%A6%AD%E0%A6%BE%E0%A7%B0%E0%A6%A4%E0%A7%80%E0%A6%AF%E0%A6%BC_%E0%A6%9A%E0%A6%B2%E0%A6%9A%E0%A7%8D%E0%A6%9A%E0%A6%BF%E0%A6%A4%E0%A7%8D%E0%A7%B0%E0%A7%B0_%E0%A6%85%E0%A6%AD%E0%A6%BF%E0%A6%A8%E0%A7%87%E0%A6%A4%E0%A6%BE%E0%A6%B8%E0%A6%95%E0%A6%B2
# Found the URL: https://www.wikidata.org/wiki/Special:EntityPage/Q1291621#sitelinks-wikipedia
# Found the URL: //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# Found the URL: //creativecommons.org/licenses/by-sa/3.0/
# Found the URL: //foundation.wikimedia.org/wiki/Terms_of_Use
# Found the URL: //foundation.wikimedia.org/wiki/Privacy_policy
# Found the URL: //www.wikimediafoundation.org/
# Found the URL: https://foundation.wikimedia.org/wiki/Privacy_policy
# Found the URL: /wiki/Wikipedia:About
# Found the URL: /wiki/Wikipedia:General_disclaimer
# Found the URL: //en.wikipedia.org/wiki/Wikipedia:Contact_us
# Found the URL: https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# Found the URL: https://stats.wikimedia.org/#/en.wikipedia.org
# Found the URL: https://foundation.wikimedia.org/wiki/Cookie_statement
# Found the URL: //en.m.wikipedia.org/w/index.php?title=List_of_Indian_film_actors&mobileaction=toggle_view_mobile
# Found the URL: https://wikimediafoundation.org/
# Found the URL: https://www.mediawiki.org/

# %%
import requests
from bs4 import BeautifulSoup


url = 'https://en.wikipedia.org/wiki/Shah_Rukh_Khan'
#url = 'https://robogenius.in/'
response = requests.get(url)
print(response.status_code)
#data_content = response.content
#print(response.content)
#data_json = response.json()
#print(response.json)
#data_body = response.request.body
#headers = response.headers
#print(response.headers) #try get function
#print(response.headers['Content-Type'])
#response.headers['Last-Modified']
# Out:
# 200

# %%
#print(data)
soup = BeautifulSoup(response.content, 'html.parser')
print(soup.title.string)
bio = soup.find('table')
rows = bio.find('tr')
print(rows.text)
title = []
value = []
for item in bio:
    rows = bio.find_all('tr')
    for row in rows:
        cells = row.find_all('td')
        title.append(cells)
# Out:
# Shah Rukh Khan - Wikipedia
# Shah Rukh Khan

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
url = 'https://en.wikipedia.org/wiki/Shah_Rukh_Khan'
response = urlopen(url) 
soup = BeautifulSoup(response, 'html.parser')
bio = soup.find('table')
#print(results)
#print(bio)
#print(soup.title)
#print(soup.title.string)
#print(soup.prettify())
title = []
value = []
